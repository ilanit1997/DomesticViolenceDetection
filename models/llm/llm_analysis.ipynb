# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

# %% [markdown]
# # **Multiclass**

# %%
df =pd.read_excel("/content/gpt labeling.xlsx")
df

# %%
labels =["low", "medium", "high"]

# %% [markdown]
# ##**Zero-shot**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
y_true = df['true label'].values
y_pred = df['zero-shot'].values
cm = confusion_matrix(y_true, y_pred,labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
font = {'family' : 'normal',
    'size'   : 18}
plt.rc('font', **font)
disp.plot(cmap=plt.cm.Blues)
plt.show()
#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_true, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_true, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_true, y_pred))
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# Accuracy: 0.80
#
# Micro Precision: 0.80
# Micro Recall: 0.80
# Micro F1-score: 0.80
#
# Macro Precision: 0.81
# Macro Recall: 0.80
# Macro F1-score: 0.80
#
# Weighted Precision: 0.81
# Weighted Recall: 0.80
# Weighted F1-score: 0.80
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#         high       0.69      0.90      0.78        10
#          low       1.00      0.90      0.95        10
#       medium       0.75      0.60      0.67        10
#
#     accuracy                           0.80        30
#    macro avg       0.81      0.80      0.80        30
# weighted avg       0.81      0.80      0.80        30

# %% [markdown]
# ## **Few-shot**

# %%
y_true = df['true label'].values
y_pred = df['few-shot'].values
cm = confusion_matrix(y_true, y_pred,labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.show()
#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_true, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_true, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_true, y_pred))
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# Accuracy: 0.70
#
# Micro Precision: 0.70
# Micro Recall: 0.70
# Micro F1-score: 0.70
#
# Macro Precision: 0.73
# Macro Recall: 0.70
# Macro F1-score: 0.68
#
# Weighted Precision: 0.73
# Weighted Recall: 0.70
# Weighted F1-score: 0.68
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#         high       0.59      1.00      0.74        10
#          low       1.00      0.80      0.89        10
#       medium       0.60      0.30      0.40        10
#
#     accuracy                           0.70        30
#    macro avg       0.73      0.70      0.68        30
# weighted avg       0.73      0.70      0.68        30

# %% [markdown]
# # **Binary**

# %%
df2= df.replace('high', 'combined', regex=True)
df2=df2.replace('medium', 'combined', regex=True)
df2=df2.replace('combined', 'medium + high', regex=True)

df2
# Out:
#    question_0_This post is:     true label  index  originalIndex  \
# 0                  relevant  medium + high     72              3
# 1                  relevant  medium + high    188            101
# 2                  relevant            low    109             28
# 3                  relevant  medium + high    169             44
# 4                  relevant            low    107             71
# 5                  relevant  medium + high    131             88
# 6                  relevant  medium + high     76             93
# 7                  relevant  medium + high     92            105
# 8                  relevant  medium + high    132            108
# 9                  relevant  medium + high     95            111
# 10                 relevant            low     51            128
# 11                 relevant            low    143            139
# 12                 relevant            low    144            146
# 13                 relevant            low    112            147
# 14                 relevant  medium + high    128            149
# 15                 relevant  medium + high     93            164
# 16                 relevant  medium + high    124            182
# 17                 relevant            low    108            191
# 18                 relevant            low    148            219
# 19                 relevant  medium + high     67            238
# 20                 relevant            low     50            241
# 21                 relevant  medium + high    139            242
# 22                 relevant  medium + high     46            193
# 23                 relevant  medium + high    133            264
# 24                 relevant  medium + high    135            294
# 25                 relevant  medium + high    129            299
# 26                 relevant  medium + high     91            301
# 27                 relevant            low    149            304
# 28                 relevant  medium + high    178            305
# 29                 relevant  medium + high     77            306
#
#                   part                                              title  \
# 0          exploration  I (20F) accidentally looked at another man and...
# 1               part3A                     F-32, M-32, together 12 years.
# 2           evaluation  My (F22) first experience of cohabiting with m...
# 3               part3A  I 26F am tired of my boyfriend 26M drinking ha...
# 4           evaluation  Is my (21F) partner (22M) right for being upse...
# 5           evaluation  My (31F) fianc? (29M) makes more than 41% more...
# 6          exploration  How can I repair my self-esteem after having i...
# 7          exploration  26f in a relationship with a 25m. Issues with ...
# 8           evaluation  I (f23) am unhappy with our sex life and want ...
# 9          exploration  I (22F) think I might be in a toxic relationsh...
# 10         exploration       I (F23) looked through my bfן¿½s (M23) phone
# 11          evaluation  Is the amount of time my boyfriend (26M) wants...
# 12          evaluation  My 22F boyfriend 22M past is still in our ever...
# 13          evaluation  My (26F) partner (27M) swears he didnן¿½t do i...
# 14          evaluation  Is my boyfriendן¿½s (32M) behavior possessive ...
# 15         exploration         I (21 F) want to reach out to my ex (22 M)
# 16          evaluation        Will my BPD ex (M22) come back to me (F20)?
# 17          evaluation  Did I (23F) get lovebombed and manipulated by ...
# 18          evaluation  Itן¿½s hard for me (F20) to have serious conve...
# 19         exploration  I (31f) have been thinking a lot about other p...
# 20         exploration  I (27f) have suspicion my boyfriend (33m) of 7...
# 21          evaluation  Wish I (35 F) Could communicate better with my...
# 22  pre_exploration_t2  Ive (24F) tried to leave my husband (25M) 3 ti...
# 23          evaluation  My 26F boyfriend 26M wants to text and snapcha...
# 24          evaluation  HELP, I (22f) dont understand why my bf (21m) ...
# 25          evaluation  My (18F) first break up and narcissistic boyfr...
# 26         exploration  Spouses having financial disagreement (m37, f3...
# 27          evaluation  I (26F) really do not like my BF (28M)ן¿½s fem...
# 28              part3A  My ex bf (m23) thinks iֳ¯ֲ¿ֲ½m (f23) a stalker...
# 29         exploration  He (M43) left me (F26) and kicked me out, but ...
#
#                                                  text      zero-shot  \
# 0   For context I am 21 f and my bf 20 have been h...  medium + high
# 1   My husband tells me no other guy will ever wan...  medium + high
# 2   Hello people from Reddit. This is my first tim...  medium + high
# 3   Im 26F my boyfriend is 26M. We have been toget...  medium + high
# 4   My (21F) partner (22M) gets hurt when I do not...            low
# 5   Edit: I forgot to include that we put the wedd...  medium + high
# 6   &#x200B;\n\n&#x200B;\n\nMy (21F) boyfriend (22...  medium + high
# 7   Im 26f. My partner is 25m. Weve been together ...  medium + high
# 8   Hey all! I genuinely believe you should trust ...  medium + high
# 9   \nSo me (22F) and this guy (22M) met about 10 ...  medium + high
# 10  I (F23) looked through my bfן¿½s (M23) phone. ...            low
# 11  Hi! Iן¿½ve been in a relationship with my boyf...            low
# 12  The issue is that his past is in my everyday l...            low
# 13  Im in a long term relationship with the man of...            low
# 14  Some background first- My current boyfriend an...  medium + high
# 15  21 F) have been wanting to reach out to my ex ...  medium + high
# 16  \nFor context, our relationship has been quite...  medium + high
# 17  I (23F) met this guy (23M) on a dating app, we...            low
# 18  Thereן¿½s been a couple of arguments that we h...            low
# 19  My husband isnt it for me anymore, he has been...  medium + high
# 20  I (27f) have been with my boyfriend (33m) for ...            low
# 21  Sometimes I dont respond fast enough to my hus...  medium + high
# 22  My ex(?) and I have had a very difficult relat...  medium + high
# 23  \nMe 26F and my boyfriend 26M have been dating...  medium + high
# 24  Its been 9 months were together and also is my...  medium + high
# 25  Me (18F) and him (21M)\n\n\nWeve been together...  medium + high
# 26  Strangers of the internet I come to you becaus...  medium + high
# 27  The worst part is, she hasnן¿½t done anything ...            low
# 28  \n\nHi guys, I am writing for advice on a situ...  medium + high
# 29  \nHe kicked me out of his apartment, then when...  medium + high
#
#                                      zero-explanation       few-shot  \
# 0   Explanation: The post shows clear signs of emo...  medium + high
# 1   The post presents a concerning pattern of emot...  medium + high
# 2   While there is no explicit evidence of physica...  medium + high
# 3   Explanation: The boyfriends chronic alcohol us...  medium + high
# 4   Explanation: The post describes a common relat...            low
# 5   This post reveals tension and potential financ...  medium + high
# 6   This relationship shows several warning signs ...  medium + high
# 7   Explanation: The partners controlling behavior...  medium + high
# 8   Explanation: There is evidence of physical and...  medium + high
# 9   The post reflects recurring harmful patterns o...  medium + high
# 10  Explanation: The post describes issues regardi...            low
# 11  The post indicates a relationship imbalance an...            low
# 12  While this relationship seems to have emotiona...            low
# 13  While the post indicates some anxiety and trus...            low
# 14  Explanation: The post medium + highlights seve...  medium + high
# 15  Explanation: The female partner describes her ...  medium + high
# 16  Explanation: The post describes an unstable an...  medium + high
# 17  The situation described does not appear to inv...            low
# 18  The situation described in this post does refl...  medium + high
# 19  The post suggests severe warning signs of an u...  medium + high
# 20  Explanation: The post mainly discusses possibl...            low
# 21  Explanation: The husbands consistent yelling a...  medium + high
# 22  Explanation: The female reports experiencing e...  medium + high
# 23  Explanation: This post shows multiple warning ...  medium + high
# 24  Explanation: The post indicates a medium + hig...  medium + high
# 25  Explanation: The post details various concerni...  medium + high
# 26  Explanation: The situation suggests some eleme...  medium + high
# 27  Explanation: This post suggests an interperson...            low
# 28  Explanation: This situation shows multiple red...  medium + high
# 29  Explanation: The post indicates emotional turm...  medium + high
#
#                                       few-explanation
# 0   The post illustrates recurring patterns of emo...
# 1   The post shows multiple signs of emotional abu...
# 2   The post suggests emotional stress, imbalance ...
# 3   Explanation: The post suggests severe alcohol ...
# 4   Explanation: The situation described in the po...
# 5   The post shows signs of financial stress and p...
# 6   This post details a history of emotional and p...
# 7   The post exhibits multiple signs of emotional ...
# 8   The post illustrates numerous instances of phy...
# 9   This post shows clear signs of emotional abuse...
# 10  This post indicates relationship issues primar...
# 11  The posters concerns seem to largely stem from...
# 12  While the situation is emotionally stressful d...
# 13  While there is a perceived breach of trust due...
# 14  The post indicates the presence of emotional a...
# 15   The post reveals previous incidents of emotio...
# 16  This post indicates repeated patterns of emoti...
# 17  The situation presented here seems to indicate...
# 18  The boyfriends lack of communication and recip...
# 19  This post suggests that the woman is in a pote...
# 20  Although there are signs of potential dishones...
# 21  This post reveals a concerning pattern of verb...
# 22  This post indicates multiple warning signs and...
# 23  The boyfriends extreme need for control, demon...
# 24   The post reveals recurring patterns of severe...
# 25  This post outlines a series of narcissistic ab...
# 26  This post indicates financial abuse and emotio...
# 27  While this situation can cause emotional stres...
# 28  This situation features emotional abuse, manip...
# 29  There are signs of emotional abuse, including ...

# %%
labels =["low", "medium + high"]

# %% [markdown]
# ##**Zero-shot**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
y_true = df2['true label'].values
y_pred = df2['zero-shot'].values
cm = confusion_matrix(y_true, y_pred,labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
font = {'family' : 'normal',
    'size'   : 18}
plt.rc('font', **font)
disp.plot(cmap=plt.cm.Blues)
plt.show()
#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_true, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_true, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_true, y_pred))
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# Accuracy: 0.97
#
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.98
# Macro Recall: 0.95
# Macro F1-score: 0.96
#
# Weighted Precision: 0.97
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Classification Report
#
#                precision    recall  f1-score   support
#
#           low       1.00      0.90      0.95        10
# medium + high       0.95      1.00      0.98        20
#
#      accuracy                           0.97        30
#     macro avg       0.98      0.95      0.96        30
#  weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ##**Few-shot**

# %%
y_true = df2['true label'].values
y_pred = df2['few-shot'].values
cm = confusion_matrix(y_true, y_pred,labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.show()
#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_true, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_true, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_true, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_true, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_true, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_true, y_pred))
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'normal' not found.
# Accuracy: 0.93
#
# Micro Precision: 0.93
# Micro Recall: 0.93
# Micro F1-score: 0.93
#
# Macro Precision: 0.95
# Macro Recall: 0.90
# Macro F1-score: 0.92
#
# Weighted Precision: 0.94
# Weighted Recall: 0.93
# Weighted F1-score: 0.93
#
# Classification Report
#
#                precision    recall  f1-score   support
#
#           low       1.00      0.80      0.89        10
# medium + high       0.91      1.00      0.95        20
#
#      accuracy                           0.93        30
#     macro avg       0.95      0.90      0.92        30
#  weighted avg       0.94      0.93      0.93        30
